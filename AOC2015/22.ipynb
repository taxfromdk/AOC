# %%
class spell:
    def __init__(s, l, sender, reciever):
        s.l = l #lifetime
        s.age = 0
    
    
        
class spell_missile(spell):
    def __init__(s):
        super(spell_missile, s).init(53, 1)
        
    def update(s):
        #damage, heal, mana 
        return 4, 0, 0
    
class drain(spell):
    def __init__(s):
        super(drain, s).__init__(73, 1)
    
class shield(spell):
    def __init__(s):
        super(shield,s).__init__(113, 6)
    
    def update(s):
        return
        
class poison(spell):
    def __init__(s):
        super(shield,s).__init__(173, 6)
    
    def update(s):
        return     

class recharge(spell):
    def __init__(s):
        super(shield,s).__init__(229, 6)
    
    def update(s):
        return     

spellmenu = {}
spellmenu["missile"]=53
spellmenu["drain"]=73
spellmenu["shield"]=113
spellmenu["poison"]=173
spellmenu["recharge"]=229


#players
class player:
    def __init__(s, hp):
        s.hp = hp
    
    def p(s):
        pass
        
class boss(player):
    def __init__(s, hp, d):
        super(boss,s).__init__(hp)
        s.d = d
    
    def p(s):
        print("B",s.hp, s.d)
        
class wizard(player):
    def __init__(s, hp, m):
        super(wizard,s).__init__(hp)
        s.m = m
        
    def p(s):
        print("W",s.hp, s.m)
        
        
        
b = boss(55,8)
b.p()

w = wizard(50,500)
w.p()


#Magic Missile costs 53 mana. It instantly does 4 damage.
#Drain costs 73 mana. It instantly does 2 damage and heals you for 2 hit points.
#Shield costs 113 mana. It starts an effect that lasts for 6 turns. While it is active, your armor is increased by 7.
#Poison costs 173 mana. It starts an effect that lasts for 6 turns. At the start of each turn while it is active, it deals the boss 3 damage.
#Recharge costs 229 mana. It starts an effect that lasts for 5 turns. At the start of each turn while it is active, it gives you 101 new mana
# Out:
# B 55 8
# W 50 500
