# %%
t=[]
t.append(("1", "11"))
t.append(("11","21"))
t.append(("21","1211"))
t.append(("1211","111221"))
t.append(("111221","312211"))
t.append(("1321131112",None))


def e(i):
    l=i[0]
    c=0
    o=""
    for x in range(len(i)+1):
        if x == len(i) or l != i[x]:
            o += str(c)
            o += l
            c=0
            if x==len(i):
                return o
        l=i[x]
        c+=1

for a,b in t:
    o=e(a)
    if b:
        if o == b:
            print(a, "becomes", o, "ok")
        else:
            print(a, "becomes", o, "(", b, ")fail")
    else:
        print(a, "becomes", o)

        
q0=t[-1][0]
for i in range(50):
    q0=e(q0)
    print(i+1,len(q0))
# Out:
# 1 becomes 11 ok
# 11 becomes 21 ok
# 21 becomes 1211 ok
# 1211 becomes 111221 ok
# 111221 becomes 312211 ok
# 1321131112 becomes 11131221133112
# 1 14
# 2 16
# 3 22
# 4 34
# 5 42
# 6 56
# 7 76
# 8 96
# 9 126
# 10 172
# 11 226
# 12 286
# 13 382
# 14 500
# 15 638
# 16 860
# 17 1118
# 18 1420
# 19 1890
# 20 2466
# 21 3182
# 22 4178
# 23 5460
# 24 7066
# 25 9224
# 26 12100
# 27 15684
# 28 20474
# 29 26744
# 30 34772
# 31 45370
# 32 59214
# 33 77146
# 34 100396
# 35 131124
# 36 170930
# 37 222442
# 38 290526
# 39 378526
# 40 492982
# 41 643280
# 42 838402
# 43 1092528
# 44 1424438
# 45 1857356
# 46 2420082
# 47 3155270
# 48 4114514
# 49 5361162
# 50 6989950
