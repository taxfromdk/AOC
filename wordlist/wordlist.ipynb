# %%
import re

for w in open("master.txt").readlines():
    w=w.strip().lower()
    for r in re.findall("[a-z]?tax[a-z]?",w):
        print(w)
# Out:
# aerotaxes
# aerotaxis
# aftertax
# anthotaxies
# anthotaxy
# antitax
# artaxerxes
# ataxia
# ataxias
# ataxic
# ataxics
# ataxies
# ataxy
# athrotaxis
# austrotaxus
# betaxed
# biotaxy
# cefotaxime
# cephalotaxaceae
# cephalotaxus
# chemotaxes
# chemotaxis
# chemotaxonomic
# chemotaxonomies
# chemotaxonomist
# chemotaxonomists
# chemotaxonomy
# curtaxe
# curtaxes
# cytotaxes
# cytotaxis
# cytotaxonomic
# cytotaxonomically
# cytotaxonomies
# cytotaxonomist
# cytotaxonomists
# cytotaxonomy
# diplotaxis
# dystaxia
# dystaxias
# epistaxes
# epistaxis
# epistaxises
# epitaxes
# epitaxial
# epitaxially
# epitaxic
# epitaxies
# epitaxis
# epitaxy
# eutaxia
# eutaxias
# eutaxies
# eutaxite
# eutaxites
# eutaxitic
# eutaxy
# geotaxes
# geotaxis
# geotaxy
# heliotaxes
# heliotaxis
# heterotaxes
# heterotaxia
# heterotaxias
# heterotaxic
# heterotaxies
# heterotaxis
# heterotaxy
# homotaxes
# homotaxial
# homotaxially
# homotaxic
# homotaxis
# hydrotaxes
# hydrotaxis
# hypotaxes
# hypotaxis
# ...
